# %% [markdown]
# <a href="https://colab.research.google.com/github/janputra/Neural-Networks-Practice/blob/main/TF2_0_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
  import pandas as pd
  import numpy as np
  import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv
# Out:
# --2020-09-04 09:08:51--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2302 (2.2K) [text/plain]
# Saving to: ‘moore.csv’
#
# moore.csv           100%[===================>]   2.25K  --.-KB/s    in 0s
#
# 2020-09-04 09:08:51 (36.4 MB/s) - ‘moore.csv’ saved [2302/2302]

# %%
data= pd.read_csv('moore.csv',header=None).values
x= data[:,0].reshape(-1,1)
y=data[:,1]

# %%
y= np.log(y)

# %%
x=x-x.mean()

# %%
from tensorflow.keras import models 
from tensorflow.keras import layers

# %%
model =models.Sequential()

model.add(layers.Input(shape=(1,)))
model.add(layers.Dense(1))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),loss='mse')

r=model.fit(x,y, epochs=300)
# Out:
# Epoch 1/300
# 6/6 [==============================] - 0s 2ms/step - loss: 33.4744
# Epoch 2/300
# 6/6 [==============================] - 0s 1ms/step - loss: 32.7852
# Epoch 3/300
# 6/6 [==============================] - 0s 1ms/step - loss: 32.0407
# Epoch 4/300
# 6/6 [==============================] - 0s 1ms/step - loss: 31.3039
# Epoch 5/300
# 6/6 [==============================] - 0s 1ms/step - loss: 30.6568
# Epoch 6/300
# 6/6 [==============================] - 0s 1ms/step - loss: 30.0198
# Epoch 7/300
# 6/6 [==============================] - 0s 1ms/step - loss: 29.4448
# Epoch 8/300
# 6/6 [==============================] - 0s 1ms/step - loss: 28.7804
# Epoch 9/300
# 6/6 [==============================] - 0s 1ms/step - loss: 28.1767
# Epoch 10/300
# 6/6 [==============================] - 0s 1ms/step - loss: 27.5571
# Epoch 11/300
# 6/6 [==============================] - 0s 1ms/step - loss: 26.9105
# Epoch 12/300
# 6/6 [==============================] - 0s 1ms/step - loss: 26.4235
# ...

# %%
plt.plot(r.history['loss'],label='loss')

# %%
print(model.layers)

# %%
print(model.layers[0].get_weights())
# Out:
# [array([[0.34265664]], dtype=float32), array([17.77343], dtype=float32)]

# %%
print(model.layers[0].get_weights()[0])
# Out:
# [[0.34265664]]

# %%
print(model.layers[0].get_weights()[1][0])
# Out:
# 17.77343

# %%
yhat=model.predict(x).flatten()

plt.scatter(x,y)
plt.plot(x,yhat)
